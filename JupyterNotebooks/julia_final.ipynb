# %%
using Distributions
using Interpolations
using Distributed
using DataFrames
using Printf
using JLD
using CSV
using Dierckx
using Dates
# using PyPlot
# using Seaborn

main_path = "/home/artur/BondPricing"
module_path = string(main_path, "/", "Julia/modules/")
include(string(module_path, "/", "TestFunctions.jl"))
modls = ["ModelObj", "AnalyticFunctions", 
         "BondPrInterp", "EqFinDiff", 
         "Batch", "ModelPlots"] #,"FullInfoEq"]#, "JointEq"]
for modl in modls
    include(string(joinpath(module_path, modl), "/", modl, ".jl"))
end

ENV["LINES"] = 750
# Out:
# WARNING: replacing module TestFunctions.
# WARNING: replacing module ModelObj.
# WARNING: replacing module AnalyticFunctions.
# WARNING: replacing module BondPrInterp.
# WARNING: replacing module EqFinDiff.
# WARNING: replacing module Batch.
# WARNING: replacing module ModelPlots.
# 750

# %% [markdown]
# # CVM adn SVM Diagnostics and Compilation

# %%
# Set m=1. and model = "cvm"
plot_script_path = string(main_path, "/Julia/Batch/")
plot_script_name = "diag_compilation.jl"
cvm_res = include(string(plot_script_path, "/", plot_script_name))
# Out:
# WARNING: replacing module ModelObj.
# WARNING: replacing module AnalyticFunctions.
# WARNING: replacing module BondPrInterp.
# WARNING: replacing module EqFinDiff.
# WARNING: replacing module Batch.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
#  22.986740 seconds (49.24 M allocations: 3.263 GiB, 6.35% gc time)
# Saving compiled results...
#  23.622708 seconds (50.73 M allocations: 3.335 GiB, 6.31% gc time)
# Dict{Symbol,Any} with 4 entries:
#   :m      => 1.0
#   :model  => "cvm"
#   :diag   => 208×17 DataFrame. Omitted printing of 12 columns…
#   :opt_fv => 208×36 DataFrame. Omitted printing of 30 columns…

# %%
# Set m=1. and model = "svm"
plot_script_path = string(main_path, "/Julia/Batch/")
plot_script_name = "diag_compilation.jl"
svm_res = include(string(plot_script_path, "/", plot_script_name))
# Out:
# WARNING: replacing module ModelObj.
# WARNING: replacing module AnalyticFunctions.
# WARNING: replacing module BondPrInterp.
# WARNING: replacing module EqFinDiff.
# WARNING: replacing module Batch.
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   4.231384 seconds (9.39 M allocations: 558.531 MiB, 8.22% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.198784 seconds (811.42 k allocations: 137.112 MiB, 11.32% gc time)
#   5.718768 seconds (15.41 M allocations: 755.472 MiB, 6.65% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   1.528457 seconds (3.39 M allocations: 253.223 MiB, 7.33% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -38.59249993853444
# phi1: 0.9999999999999998
# pv_rfdebt: 52.23346106318344
# debt_abs_per_diff: 5.86741213711521e-9
# eq_abs_per_diff: 0.0009113235577835247
# Equity Vmax: 272.8593235477421
#
# eq_max: 234.26228364373813
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.07289791107177734
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 58.37942884960713
# Equity Core Function Computation Time: 1.5991151332855225
# Total Equity FD Core Function Computation Time: 2.486854076385498
# Total computation time: 5.126817941665649
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.209420 seconds (811.42 k allocations: 137.113 MiB, 15.07% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.187250 seconds (811.43 k allocations: 137.113 MiB, 9.81% gc time)
#   0.676756 seconds (319.04 k allocations: 80.760 MiB, 24.97% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.255777 seconds (10.74 k allocations: 86.051 MiB, 6.30% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -38.66733099777386
# phi1: 0.9999999999999998
# pv_rfdebt: 51.37694546635179
# debt_abs_per_diff: 4.807545523404533e-9
# eq_abs_per_diff: 0.000849523723850898
# Equity Vmax: 272.8593235477421
#
# eq_max: 234.1878431833643
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008172988891601562
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 58.515979278409205
# Equity Core Function Computation Time: 0.0666038990020752
# Total Equity FD Core Function Computation Time: 0.12330508232116699
# Total computation time: 0.15506911277770996
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.345874 seconds (811.48 k allocations: 137.113 MiB, 47.74% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.189006 seconds (811.43 k allocations: 137.112 MiB, 9.91% gc time)
#   0.507379 seconds (160.23 k allocations: 72.693 MiB, 2.41% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.247513 seconds (10.56 k allocations: 86.043 MiB, 4.86% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -38.6931729792833
# phi1: 0.9999999999999998
# pv_rfdebt: 51.099185737354745
# debt_abs_per_diff: 4.373478026949581e-9
# eq_abs_per_diff: 0.0008301206833901539
# Equity Vmax: 272.8593235477421
#
# eq_max: 234.16212179690885
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008327007293701172
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 58.55615372999389
# Equity Core Function Computation Time: 0.1625511646270752
# Total Equity FD Core Function Computation Time: 0.25511693954467773
# Total computation time: 0.2839641571044922
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.199711 seconds (811.47 k allocations: 137.116 MiB, 9.94% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.184390 seconds (811.43 k allocations: 137.112 MiB, 8.33% gc time)
#   0.459043 seconds (158.90 k allocations: 72.526 MiB, 2.42% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.250617 seconds (10.58 k allocations: 86.045 MiB, 4.91% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -38.7434021503803
# phi1: 0.9999999999999998
# pv_rfdebt: 50.5522007535661
# debt_abs_per_diff: 1.0044966661699401e-8
# eq_abs_per_diff: 0.0009829475913783307
# Equity Vmax: 259.86602242642107
#
# eq_max: 221.11762656572031
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008169889450073242
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 58.63489650369148
# Equity Core Function Computation Time: 0.16011691093444824
# Total Equity FD Core Function Computation Time: 0.2473142147064209
# Total computation time: 0.2779350280761719
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.212601 seconds (811.47 k allocations: 137.113 MiB, 14.77% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.200997 seconds (811.43 k allocations: 137.113 MiB, 12.83% gc time)
#   0.482964 seconds (157.68 k allocations: 74.551 MiB, 2.55% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.378028 seconds (11.21 k allocations: 132.377 MiB, 4.36% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -38.81130009504101
# phi1: 0.9999999999999998
# pv_rfdebt: 50.04138669399316
# debt_abs_per_diff: 9.778323373722875e-9
# eq_abs_per_diff: 0.0009410944343759117
# Equity Vmax: 259.86602242642107
#
# eq_max: 221.04999520210032
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008180856704711914
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 58.680755673357304
# Equity Core Function Computation Time: 0.16419601440429688
# Total Equity FD Core Function Computation Time: 0.2702138423919678
# Total computation time: 0.29806089401245117
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.200416 seconds (811.47 k allocations: 137.113 MiB, 9.91% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.184628 seconds (811.43 k allocations: 137.112 MiB, 8.40% gc time)
#   0.617142 seconds (167.58 k allocations: 73.837 MiB, 1.83% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.250330 seconds (10.73 k allocations: 86.067 MiB, 4.97% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -37.23931632262669
# phi1: 0.9999999999999998
# pv_rfdebt: 50.39993371287197
# debt_abs_per_diff: 1.2494556579881126e-8
# eq_abs_per_diff: 0.0009652403408721369
# Equity Vmax: 259.86602242642107
#
# eq_max: 222.62199287146115
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008179187774658203
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 59.52950373601709
# Equity Core Function Computation Time: 0.16251015663146973
# Total Equity FD Core Function Computation Time: 0.2496190071105957
# Total computation time: 0.2807190418243408
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.203535 seconds (811.47 k allocations: 137.116 MiB, 11.55% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.186851 seconds (811.43 k allocations: 137.113 MiB, 9.79% gc time)
#   0.444274 seconds (165.11 k allocations: 73.496 MiB, 2.66% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.254965 seconds (10.57 k allocations: 86.053 MiB, 4.72% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -37.24038376911061
# phi1: 0.9999999999999998
# pv_rfdebt: 49.481169674042505
# debt_abs_per_diff: 1.2711143343120268e-8
# eq_abs_per_diff: 0.0008924311407366917
# Equity Vmax: 259.86602242642107
#
# eq_max: 222.62138379028963
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008175134658813477
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 59.76721034940023
# Equity Core Function Computation Time: 0.16312003135681152
# Total Equity FD Core Function Computation Time: 0.2722780704498291
# Total computation time: 0.29973292350769043
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.200105 seconds (811.47 k allocations: 137.116 MiB, 9.95% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.183572 seconds (811.43 k allocations: 137.112 MiB, 7.86% gc time)
#   0.505515 seconds (166.36 k allocations: 73.677 MiB, 2.17% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.250003 seconds (10.58 k allocations: 86.055 MiB, 4.81% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -37.234907252653656
# phi1: 0.9999999999999998
# pv_rfdebt: 49.17439576432667
# debt_abs_per_diff: 1.2740033621101886e-8
# eq_abs_per_diff: 0.0008689894482490329
# Equity Vmax: 259.86602242642107
#
# eq_max: 222.6270057432174
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008183002471923828
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 59.84921369359708
# Equity Core Function Computation Time: 0.16103506088256836
# Total Equity FD Core Function Computation Time: 0.24886488914489746
# Total computation time: 0.279526948928833
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.207926 seconds (811.47 k allocations: 137.113 MiB, 12.82% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.187396 seconds (811.43 k allocations: 137.112 MiB, 9.22% gc time)
#   0.445922 seconds (163.90 k allocations: 75.464 MiB, 2.64% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.248458 seconds (10.57 k allocations: 86.051 MiB, 4.62% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -37.19334318145524
# phi1: 0.9999999999999998
# pv_rfdebt: 48.53252477356037
# debt_abs_per_diff: 1.2986266094397139e-8
# eq_abs_per_diff: 0.0008212805573627381
# Equity Vmax: 259.86602242642107
#
# eq_max: 222.66886430431617
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008337974548339844
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 60.04579791744789
# Equity Core Function Computation Time: 0.16269588470458984
# Total Equity FD Core Function Computation Time: 0.2553870677947998
# Total computation time: 0.282926082611084
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.200733 seconds (811.47 k allocations: 137.116 MiB, 9.99% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.184004 seconds (811.43 k allocations: 137.112 MiB, 8.03% gc time)
#   0.498090 seconds (168.05 k allocations: 76.251 MiB, 2.29% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.252052 seconds (10.59 k allocations: 86.062 MiB, 5.00% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -37.17111844887908
# phi1: 0.9999999999999998
# pv_rfdebt: 47.92729398778383
# debt_abs_per_diff: 4.427336371467823e-8
# eq_abs_per_diff: 0.0009647429878109034
# Equity Vmax: 247.4914499299248
#
# eq_max: 210.31565916614406
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.00816798210144043
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 60.20990591726171
# Equity Core Function Computation Time: 0.16072607040405273
# Total Equity FD Core Function Computation Time: 0.25072789192199707
# Total computation time: 0.2771930694580078
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.207663 seconds (811.47 k allocations: 137.114 MiB, 13.17% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.187102 seconds (811.43 k allocations: 137.112 MiB, 9.28% gc time)
#   0.387251 seconds (165.07 k allocations: 73.364 MiB, 2.94% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.248952 seconds (10.57 k allocations: 86.049 MiB, 4.63% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -36.582519474884464
# phi1: 0.9999999999999998
# pv_rfdebt: 49.49571991563299
# debt_abs_per_diff: 1.011508011412452e-8
# eq_abs_per_diff: 0.0008913266509129054
# Equity Vmax: 259.86602242642107
#
# eq_max: 223.27931956360393
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008359909057617188
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 60.092890896670845
# Equity Core Function Computation Time: 0.1632981300354004
# Total Equity FD Core Function Computation Time: 0.2697939872741699
# Total computation time: 0.2974669933319092
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.201014 seconds (811.47 k allocations: 137.113 MiB, 9.87% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.183295 seconds (811.43 k allocations: 137.112 MiB, 7.72% gc time)
#   0.504432 seconds (167.99 k allocations: 73.831 MiB, 2.18% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.261007 seconds (10.62 k allocations: 89.914 MiB, 4.57% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -36.56644204135313
# phi1: 0.9999999999999998
# pv_rfdebt: 48.573334082158716
# debt_abs_per_diff: 1.0916819480534542e-8
# eq_abs_per_diff: 0.0008225863091806059
# Equity Vmax: 259.86602242642107
#
# eq_max: 223.29581433317364
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008172988891601562
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 60.35543172021587
# Equity Core Function Computation Time: 0.1656510829925537
# Total Equity FD Core Function Computation Time: 0.27130699157714844
# Total computation time: 0.29897403717041016
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.211745 seconds (811.47 k allocations: 137.113 MiB, 14.03% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.185048 seconds (811.43 k allocations: 137.112 MiB, 8.38% gc time)
#   0.383873 seconds (167.53 k allocations: 73.759 MiB, 3.01% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.261773 seconds (10.73 k allocations: 86.064 MiB, 4.81% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -36.538343913146676
# phi1: 0.9999999999999998
# pv_rfdebt: 48.243393089916644
# debt_abs_per_diff: 4.2157393606396215e-8
# eq_abs_per_diff: 0.0009903912323123273
# Equity Vmax: 247.4914499299248
#
# eq_max: 210.9483441653167
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008166074752807617
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 60.46912280292477
# Equity Core Function Computation Time: 0.16138505935668945
# Total Equity FD Core Function Computation Time: 0.2505629062652588
# Total computation time: 0.28002309799194336
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.200193 seconds (811.47 k allocations: 137.113 MiB, 10.17% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.187999 seconds (811.43 k allocations: 137.113 MiB, 9.81% gc time)
#   0.363885 seconds (166.80 k allocations: 73.610 MiB, 3.22% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.248783 seconds (10.57 k allocations: 86.055 MiB, 4.82% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -36.35631177378311
# phi1: 0.9999999999999998
# pv_rfdebt: 47.431571626310955
# debt_abs_per_diff: 4.579802530462415e-8
# eq_abs_per_diff: 0.0009203268539785544
# Equity Vmax: 247.4914499299248
#
# eq_max: 211.13082816974986
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008168935775756836
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 60.850116015291235
# Equity Core Function Computation Time: 0.1632518768310547
# Total Equity FD Core Function Computation Time: 0.25439000129699707
# Total computation time: 0.2806088924407959
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.202404 seconds (811.47 k allocations: 137.116 MiB, 10.85% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.184406 seconds (811.43 k allocations: 137.112 MiB, 8.30% gc time)
#   0.353510 seconds (165.91 k allocations: 73.501 MiB, 3.25% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.250551 seconds (10.58 k allocations: 86.050 MiB, 4.92% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -36.271976148644036
# phi1: 0.9999999999999998
# pv_rfdebt: 46.767493409133
# debt_abs_per_diff: 4.9518394247571624e-8
# eq_abs_per_diff: 0.0008659472955394224
# Equity Vmax: 247.4914499299248
#
# eq_max: 211.2154991922127
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008183956146240234
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 61.089148990380444
# Equity Core Function Computation Time: 0.16063809394836426
# Total Equity FD Core Function Computation Time: 0.2505669593811035
# Total computation time: 0.2803499698638916
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.210441 seconds (811.48 k allocations: 137.116 MiB, 14.34% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.188800 seconds (811.43 k allocations: 137.112 MiB, 10.09% gc time)
#   0.402576 seconds (162.28 k allocations: 72.771 MiB, 2.95% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.259002 seconds (10.76 k allocations: 89.905 MiB, 4.67% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -35.96644539052915
# phi1: 0.9999999999999998
# pv_rfdebt: 48.61072403140568
# debt_abs_per_diff: 4.593719726945379e-10
# eq_abs_per_diff: 0.0008233802719802162
# Equity Vmax: 259.86602242642107
#
# eq_max: 223.8958599119397
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008188009262084961
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 60.63031879482352
# Equity Core Function Computation Time: 0.1658930778503418
# Total Equity FD Core Function Computation Time: 0.2768881320953369
# Total computation time: 0.30469703674316406
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.199793 seconds (811.47 k allocations: 137.116 MiB, 9.80% gc time)
# Batch object exists: true
# ...
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -17.752306668085225
# phi1: 0.9999999999999998
# pv_rfdebt: 22.88611231703727
# debt_abs_per_diff: 3.3075364920205613e-7
# eq_abs_per_diff: 0.0009021162929443949
# Equity Vmax: 514.5169494226984
#
# eq_max: 496.7646421666391
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008292913436889648
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 79.92921454900441
# Equity Core Function Computation Time: 0.1738719940185547
# Total Equity FD Core Function Computation Time: 0.27024412155151367
# Total computation time: 0.31472182273864746
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.201314 seconds (811.47 k allocations: 137.113 MiB, 10.22% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.184619 seconds (811.43 k allocations: 137.112 MiB, 8.38% gc time)
#   0.437848 seconds (151.88 k allocations: 71.046 MiB, 2.54% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.249744 seconds (10.58 k allocations: 86.000 MiB, 4.90% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -18.22925335826877
# phi1: 0.9999999999999998
# pv_rfdebt: 24.66236666425453
# debt_abs_per_diff: 1.4004498569517278e-7
# eq_abs_per_diff: 0.0009925224280246416
# Equity Vmax: 540.2427968938333
#
# eq_max: 522.0135428384089
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008288145065307617
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 78.7388556141591
# Equity Core Function Computation Time: 0.16769790649414062
# Total Equity FD Core Function Computation Time: 0.2612650394439697
# Total computation time: 0.31050777435302734
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.200432 seconds (811.47 k allocations: 137.113 MiB, 10.37% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.188186 seconds (811.43 k allocations: 137.112 MiB, 9.82% gc time)
#   0.409432 seconds (150.25 k allocations: 70.784 MiB, 2.95% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.247484 seconds (10.56 k allocations: 85.998 MiB, 4.86% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -17.696749900246143
# phi1: 0.9999999999999998
# pv_rfdebt: 23.498263984222536
# debt_abs_per_diff: 3.139009232768363e-7
# eq_abs_per_diff: 0.0009789910972212515
# Equity Vmax: 514.5169494226984
#
# eq_max: 496.82019884352167
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008449792861938477
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 79.61507319384441
# Equity Core Function Computation Time: 0.1735701560974121
# Total Equity FD Core Function Computation Time: 0.27012014389038086
# Total computation time: 0.31438493728637695
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.201169 seconds (811.47 k allocations: 137.113 MiB, 10.21% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.184144 seconds (811.43 k allocations: 137.112 MiB, 8.14% gc time)
#   0.410024 seconds (152.32 k allocations: 71.154 MiB, 2.65% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# c: 11.0 -> P Filter failed...
#   1.607146 seconds (92.84 k allocations: 564.365 MiB, 3.38% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -17.497967559427696
# phi1: 0.9999999999999998
# pv_rfdebt: 23.095489320181926
# debt_abs_per_diff: 3.2341207115475557e-7
# eq_abs_per_diff: 0.000938420625586009
# Equity Vmax: 514.5169494226984
#
# eq_max: 497.01898125380893
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.00830698013305664
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 79.92551434866179
# Equity Core Function Computation Time: 0.17358899116516113
# Total Equity FD Core Function Computation Time: 0.2727069854736328
# Total computation time: 0.3171868324279785
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.198740 seconds (811.47 k allocations: 137.116 MiB, 9.45% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.184609 seconds (811.43 k allocations: 137.112 MiB, 8.33% gc time)
#   0.403517 seconds (150.70 k allocations: 70.798 MiB, 2.75% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.271169 seconds (10.66 k allocations: 93.720 MiB, 4.46% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -17.25335478942709
# phi1: 0.9999999999999998
# pv_rfdebt: 22.5044808804196
# debt_abs_per_diff: 6.987778865801895e-7
# eq_abs_per_diff: 0.0009765408898517767
# Equity Vmax: 490.01614230733185
#
# eq_max: 472.76278683455945
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.008308172225952148
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 80.33488047746711
# Equity Core Function Computation Time: 0.17335200309753418
# Total Equity FD Core Function Computation Time: 0.24924707412719727
# Total computation time: 0.2926139831542969
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# Loading SVM object...
# Batch object file not found.
# Batch Object is incompatible! Loading surfaces only instead.
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Interpolating Bond Pricing Surfaces...
#   0.199074 seconds (811.47 k allocations: 137.116 MiB, 9.73% gc time)
# Batch object exists: true
# Interpolating bond pricing surfaces...
#   0.184291 seconds (811.43 k allocations: 137.112 MiB, 8.27% gc time)
#   0.491875 seconds (151.54 k allocations: 70.951 MiB, 2.25% gc time)
# P Filter Conditions Satisfied! Exiting...
# c: 0.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 1.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 2.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 3.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 4.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 5.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 6.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 7.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 8.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 9.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.0 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 10.5 -> P Filter success!
# P Filter Conditions Satisfied! Exiting...
# c: 11.0 -> P Filter success!
#   0.250630 seconds (10.58 k allocations: 86.002 MiB, 4.91% gc time)
# Computing Equity Vmax
# Vmax: 125.0
# phi0: -16.970530733943832
# phi1: 0.9999999999999998
# pv_rfdebt: 21.883472988118044
# debt_abs_per_diff: 7.343426870875357e-7
# eq_abs_per_diff: 0.0009101524606881996
# Equity Vmax: 490.01614230733185
#
# eq_max: 473.0456109985782
# eq_vbl: 0.0
# Computing Constant Volatility Equity Values
# Finished computing Constant Volatility Equity Values
# Time to compute Constant Volatility Equity Values: 0.00830698013305664
#
# Shape of Gamma matrix: (1498,)
# Computing equity values...
# V0: 100.0; equity: 80.78148554436598
# Equity Core Function Computation Time: 0.1679220199584961
# Total Equity FD Core Function Computation Time: 0.24072694778442383
# Total computation time: 0.28765201568603516
# Setting parameter dictionary to batch object's parameter dictionary
# Match found! Replacing row...
# 324.254747 seconds (394.07 M allocations: 105.449 GiB, 12.75% gc time)
# Saving compiled results...
# 324.650506 seconds (395.07 M allocations: 105.497 GiB, 12.75% gc time)
# Dict{Symbol,Any} with 4 entries:
#   :m      => 1.0
#   :model  => "svm"
#   :diag   => 150×17 DataFrame. Omitted printing of 12 columns…
#   :opt_fv => 150×38 DataFrame. Omitted printing of 32 columns…

# %%
svm_res[:diag]
# Out:
# UndefVarError: svm_res not defined
#
# Stacktrace:
#  [1] top-level scope at In[5]:1

# %% [markdown]
# # CVM Plots

# %%
pt = ModelPlots.PlotsObj(bt; firm_obj_fun=:firm_value, cvm_m=1., svm_m =1.)
# Out:
# Loading optimal results dataframe...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Main.ModelPlots.PlotStruct
#   bt: Main.Batch.BatchStruct
#   cvm_data: DataFrame  208 observations of 36 variables
#
#   svm_data: DataFrame  150 observations of 38 variables
#
#   obj_fun: Symbol firm_value
#   _svm_surf: DataFrame  0 observations of 0 variables
#
#   xylabels: Dict{Symbol,Array{String,1}}
#   zlabels: Dict{Symbol,Array{String,1}}

# %%
plot_script_path = string(main_path, "/Julia/Batch/plot_scripts")
include(string(plot_script_path, "/", "cvm_plots_script.jl"))
# Out:
# Loading optimal results dataframe...
# WARNING: replacing module Batch.
# WARNING: replacing module ModelObj.
# WARNING: replacing module AnalyticFunctions.
# WARNING: replacing module BondPrInterp.
# WARNING: replacing module EqFinDiff.
# WARNING: replacing module ModelPlots.
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...

# %% [markdown]
# # SVM Plots

# %% [markdown]
# ## HeatMaps and Surfaces

# %%
plot_script_path = string(main_path, "/Julia/Batch/plot_scripts")
include(string(plot_script_path, "/", "svm_plots_script.jl"))
# Out:
# Loading optimal results dataframe...
# WARNING: replacing module Batch.
# WARNING: replacing module ModelObj.
# WARNING: replacing module AnalyticFunctions.
# WARNING: replacing module BondPrInterp.
# WARNING: replacing module EqFinDiff.
# WARNING: replacing module ModelPlots.
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Unable to load optimal results dataframe. Recomputing...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
#   0.035823 seconds (9.32 k allocations: 5.114 MiB)
# Unable to load CVM data
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Unable to load optimal results dataframe. Recomputing...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
#   0.033808 seconds (9.28 k allocations: 5.113 MiB)
# Unable to load CVM data
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Unable to load optimal results dataframe. Recomputing...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
#   0.031253 seconds (9.31 k allocations: 5.114 MiB)
# Unable to load CVM data
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Unable to load optimal results dataframe. Recomputing...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
#   0.055988 seconds (9.41 k allocations: 5.115 MiB, 38.61% gc time)
# Unable to load CVM data
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Unable to load optimal results dataframe. Recomputing...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
#   0.034851 seconds (9.29 k allocations: 5.114 MiB)
# Unable to load CVM data
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Unable to load optimal results dataframe. Recomputing...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
#   0.031009 seconds (9.31 k allocations: 5.114 MiB)
# Unable to load CVM data
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Unable to load optimal results dataframe. Recomputing...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
#   0.030934 seconds (9.29 k allocations: 5.113 MiB)
# Unable to load CVM data
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Unable to load optimal results dataframe. Recomputing...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
#   0.031299 seconds (9.31 k allocations: 5.114 MiB)
# Unable to load CVM data
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Unable to load optimal results dataframe. Recomputing...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
#   0.047807 seconds (9.41 k allocations: 5.116 MiB, 36.71% gc time)
# Unable to load CVM data
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data
# Loading optimal results dataframe...
# Unable to load optimal results dataframe. Recomputing...
# Setting initial vbl value to NaN
# Setting initial vbh value to NaN
# Setting initial c value to NaN
# Setting initial p value to NaN
# Constant Volatility Model: setting vbh to vbl, lambda to NaN
#   0.032506 seconds (9.29 k allocations: 5.114 MiB)
# Unable to load CVM data
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Setting SVM Slice Data

# %% [markdown]
# # CVM vs SVM Plots

# %%
plot_script_path = string(main_path, "/Julia/Batch/plot_scripts")
include(string(plot_script_path, "/", "_cvm_vs_svm_plots_script.jl"))
# Out:
# Loading optimal results dataframe...
# WARNING: replacing module AnalyticFunctions.
# WARNING: replacing module ModelObj.
# WARNING: replacing module BondPrInterp.
# WARNING: replacing module EqFinDiff.
# WARNING: replacing module Batch.
# WARNING: replacing module ModelPlots.
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Loading optimal results dataframe...
# Figure(PyObject <Figure size 960x480 with 1 Axes>)
# Figure(PyObject <Figure size 960x480 with 1 Axes>)
# Figure(PyObject <Figure size 960x480 with 1 Axes>)
# Figure(PyObject <Figure size 960x480 with 1 Axes>)
# Figure(PyObject <Figure size 960x480 with 1 Axes>)
# Figure(PyObject <Figure size 960x480 with 1 Axes>)
# Setting parameter dictionary using (m, m_comb_num) ID pair...
# Setting parameter dictionary using (m, m_comb_num) ID pair...
